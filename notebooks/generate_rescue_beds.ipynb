# %%
import os
from pathlib import Path

import pandas as pd
import mygene

# %%
out_dir = '/diskmnt/Projects/Users/estorrs/sandbox/pecgs_bed_files'
Path(out_dir).mkdir(parents=True, exist_ok=True)

# %%
def result_to_df(result):
    data = []
    for r in result:
        genomic_pos = r['genomic_pos']
        if isinstance(genomic_pos, list):
            genomic_pos = genomic_pos[0]
        data.append([genomic_pos['chr'], genomic_pos['start'], genomic_pos['start'], r['query']])
    df = pd.DataFrame(data=data, columns=['chr', 'start', 'stop', 'gene'])
    df = df.sort_values(['chr', 'start'])
    df['chr'] = [f'chr{x}' for x in df['chr']]
    return df

# %% [markdown]
# ## CHOL

# %%
meta = pd.read_csv(
    '/diskmnt/Projects/Users/estorrs/sandbox/pecgs_bed_files/gene_lists/chol_somatic_SELECTED_DRIVER_genes.tsv',
    sep='\t'
)
meta
# Out:
#    HGNC_Gene_Symbol                                  HGNC_Gene_Name  \
# 0               APC          APC regulator of WNT signaling pathway
# 1            ARID1A                   AT-rich interaction domain 1A
# 2              BAP1                      BRCA1 associated protein 1
# 3              ECE2                  endothelin converting enzyme 2
# 4             EPHA2                                 EPH receptor A2
# 5             EPPK1                                     epiplakin 1
# 6               FYN  FYN proto-oncogene, Src family tyrosine kinase
# 7              IDH1            isocitrate dehydrogenase (NADP(+)) 1
# 8              KRAS                     KRAS proto-oncogene, GTPase
# 9             PBRM1                                     polybromo 1
# 10             PTEN                  phosphatase and tensin homolog
# 11            SMAD4                            SMAD family member 4
# 12            STK11                      serine/threonine kinase 11
# 13             TERT                telomerase reverse transcriptase
# 14             TP53                               tumor protein p53
#
#                      Gene_Alias(es)     HGNC_ID Chromosome_location  \
# 0             DP2;DP3;DP2.5;PPP1R46    HGNC:583              5q22.2
# 1   B120;P270;C10rf4;BAF250;BAF250a  HGNC:11110             1p36.11
# 2            hucep-6;KIAA0272;UCHL2    HGNC:950              3p21.1
# 3                  KIAA0604;MGC2408  HGNC:13275              3q27.1
# 4                               ECK   HGNC:3386             1p36.13
# 5                            EPIPL1  HGNC:15577              8q24.3
# 6                  SYN;SLK;MGC45350   HGNC:4037                6q21
# 7                               NaN   HGNC:5382                2q34
# 8                     KRAS1;K-Ras4B   HGNC:6407             12p12.1
# 9                BAF180;PB1;SMARCH1  HGNC:30064              3p21.1
# 10                 MMAC1;TEP1;PTEN1   HGNC:9588            10q23.31
# 11                             DPC4   HGNC:6770             18q21.2
# 12                         PJS;LKB1  HGNC:11389             19p13.3
# 13          TRT;TP2;TCS1;hEST2;EST2  HGNC:11730             5p15.33
# 14                         p53;LFS1  HGNC:11998             17p13.1
#
#                                    Reference Reference_PubMed_ID  \
# 0                          Dong et al., 2022            34971568
# 1   Farshidfar et al., 2017;Zou et al., 2014   28297679;25526346
# 2                    Farshidfar et al., 2017            28297679
# 3                           Zou et al., 2014            25526346
# 4                           Zou et al., 2014            25526346
# 5                           Zou et al., 2014            25526346
# 6                           Zou et al., 2014            25526346
# 7   Farshidfar et al., 2017;Zou et al., 2014   28297679;25526346
# 8   Farshidfar et al., 2017;Zou et al., 2014   28297679;25526346
# 9                    Farshidfar et al., 2017            28297679
# 10  Farshidfar et al., 2017;Zou et al., 2014   28297679;25526346
# 11                         Dong et al., 2022            34971568
# 12                         Dong et al., 2022            34971568
# 13                         Dong et al., 2022            34971568
# 14  Farshidfar et al., 2017;Zou et al., 2014   28297679;25526346
#
#    Reported_Mutation_Origin    Gene_Classification
# 0                   somatic  Tumor Suppressor Gene
# 1                   somatic  Tumor Suppressor Gene
# 2                   somatic  Tumor Suppressor Gene
# 3                   somatic         Not classified
# 4                   somatic         Not classified
# 5                   somatic         Not classified
# 6                   somatic         Not classified
# 7                   somatic               Oncogene
# 8                   somatic               Oncogene
# 9                   somatic  Tumor Suppressor Gene
# 10                  somatic  Tumor Suppressor Gene
# 11                  somatic  Tumor Suppressor Gene
# 12                  somatic  Tumor Suppressor Gene
# 13                  somatic               Oncogene
# 14                  somatic  Tumor Suppressor Gene

# %%
genes = sorted(set([x for x in meta['HGNC_Gene_Symbol'] if not pd.isnull(x)]))
len(genes)
# Out:
# 15

# %%
mg = mygene.MyGeneInfo()
result = mg.querymany(genes, scopes='symbol', fields='all', species='human')
# Out:
# querying 1-15...done.
# Finished.

# %%
df = result_to_df(result)
df
# Out:
#       chr      start       stop    gene
# 4    chr1   16124337   16124337   EPHA2
# 1    chr1   26693236   26693236  ARID1A
# 10  chr10   87862638   87862638    PTEN
# 8   chr12   25205246   25205246    KRAS
# 14  chr17    7661779    7661779    TP53
# 11  chr18   51028394   51028394   SMAD4
# 12  chr19    1177558    1177558   STK11
# 7    chr2  208236229  208236229    IDH1
# 2    chr3   52401008   52401008    BAP1
# 9    chr3   52545352   52545352   PBRM1
# 3    chr3  184276011  184276011    ECE2
# 13   chr5    1253147    1253147    TERT
# 0    chr5  112707498  112707498     APC
# 6    chr6  111660332  111660332     FYN
# 5    chr8  143857324  143857324   EPPK1

# %%
df.to_csv(os.path.join(out_dir, 'formatted_beds', 'pecgs_chol.bed'), index=False, header=False, sep='\t')

# %% [markdown]
# ## MM

# %%
meta = pd.read_csv(
    '/diskmnt/Projects/Users/estorrs/sandbox/pecgs_bed_files/gene_lists/mm_somatic_SELECTED_DRIVER_genes.tsv',
    sep='\t'
)
meta
# Out:
#    HGNC_Gene_Symbol                                     HGNC_Gene_Name  \
# 0             ABCF1          ATP binding cassette subfamily F member 1
# 1              APOB                                   apolipoprotein B
# 2             ARID2                       AT-rich interaction domain 2
# 3            ARID5B                      AT-rich interaction domain 5B
# 4            CDKN1B               cyclin dependent kinase inhibitor 1B
# 5            CDKN2C               cyclin dependent kinase inhibitor 2C
# 6              DIS3  DIS3 homolog, exosome endoribonuclease and 3'-...
# 7             EP300                           E1A binding protein p300
# 8          HIST1H1E                H1.4 linker histone, cluster member
# 9              IDH1               isocitrate dehydrogenase (NADP(+)) 1
# 10            KDM6A                              lysine demethylase 6A
# 11            KIF1A                           kinesin family member 1A
# 12            KMT2D                        lysine methyltransferase 2D
# 13             KRAS                        KRAS proto-oncogene, GTPase
# 14            NIPBL                       NIPBL cohesin loading factor
# 15           NOTCH1                                   notch receptor 1
# 16             NRAS                        NRAS proto-oncogene, GTPase
# 17              RB1                   RB transcriptional corepressor 1
# 18          SMARCA4  SWI/SNF related, matrix associated, actin depe...
# 19             TET2                   tet methylcytosine dioxygenase 2
# 20             TP53                                  tumor protein p53
# 21          ZFP36L1                   ZFP36 ring finger protein like 1
#
#                                        Gene_Alias(es)     HGNC_ID  \
# 0                                           EST123147     HGNC:70
# 1                                                 NaN    HGNC:603
# 2               KIAA1557;DKFZp686G052;FLJ30619;BAF200  HGNC:18037
# 3                                       FLJ21150;MRF2  HGNC:17362
# 4                                                 NaN   HGNC:1785
# 5                                           INK4C;p18   HGNC:1789
# 6                                 dis3p;RRP44;EXOSC11  HGNC:20604
# 7                                          p300;KAT3B   HGNC:3373
# 8                                 H1-4;H1.4;H1e;H1s-4   HGNC:4718
# 9                                                 NaN   HGNC:5382
# 10                                                NaN  HGNC:12637
# 11                                 ATSV;C2orf20;SPG30    HGNC:888
# 12                                        TNRC21;MLL2   HGNC:7133
# 13                                      KRAS1;K-Ras4B   HGNC:6407
# 14  IDN3;DKFZp434L1319;FLJ11203;FLJ12597;FLJ13354;...  HGNC:28862
# 15                                                NaN   HGNC:7881
# 16                                              N-ras   HGNC:7989
# 17                                        RB;PPP1R130   HGNC:9884
# 18  hSNF2b;BRG1;BAF190;SNF2;SWI2;SNF2-BETA;SNF2LB;...  HGNC:11100
# 19                                           FLJ20032  HGNC:25941
# 20                                           p53;LFS1  HGNC:11998
# 21                    RNF162B;Berg36;ERF1;TIS11B;cMG1   HGNC:1107
#
#    Chromosome_location                                          Reference  \
# 0              6p21.33             Walker et al., 2018;Maura et al., 2019
# 1               2p24.1                                   Liu et al., 2021
# 2                12q12             Walker et al., 2018;Maura et al., 2019
# 3              10q21.2                                   Liu et al., 2021
# 4              12p13.1  Walker et al., 2018;Maura et al., 2019;Liu et ...
# 5               1p32.1  Reviewed in Manier et al., 2017;Walker et al.,...
# 6              13q21.3  Reviewed in Manier et al., 2017;Walker et al.,...
# 7              22q13.2             Walker et al., 2018;Maura et al., 2019
# 8               6p22.2  Reviewed in Manier et al., 2017;Walker et al.,...
# 9                 2q34  Walker et al., 2018;Maura et al., 2019;Liu et ...
# 10              Xp11.3             Walker et al., 2018;Maura et al., 2019
# 11              2q37.3                                   Liu et al., 2021
# 12            12q13.12                                   Liu et al., 2021
# 13             12p12.1  Reviewed in Manier et al., 2017;Walker et al.,...
# 14              5p13.2                                   Liu et al., 2021
# 15              9q34.3                                   Liu et al., 2021
# 16              1p13.2  Reviewed in Manier et al., 2017;Walker et al.,...
# 17             13q14.2  Reviewed in Manier et al., 2017;Walker et al.,...
# 18             19p13.2                                   Liu et al., 2021
# 19                4q24             Walker et al., 2018;Maura et al., 2019
# 20             17p13.1  Reviewed in Manier et al., 2017;Walker et al.,...
# 21             14q24.1             Walker et al., 2018;Maura et al., 2019
#
#                     Reference_PubMed_ID Reported_Mutation_Origin  \
# 0                     29884741;31444325                  somatic
# 1                              33963182                  somatic
# 2                     29884741;31444325                  somatic
# 3                              33963182                  somatic
# 4            29884741;31444325;33963182                  somatic
# 5   27531699;29884741;31444325;33963182                  somatic
# 6   27531699;29884741;31444325;33963182                  somatic
# 7                     29884741;31444325                  somatic
# 8   27531699;29884741;31444325;33963182                  somatic
# 9            29884741;31444325;33963182                  somatic
# 10                    29884741;31444325                  somatic
# 11                             33963182                  somatic
# 12                             33963182                  somatic
# 13  27531699;29884741;31444325;33963182                  somatic
# 14                             33963182                  somatic
# 15                             33963182                  somatic
# 16  27531699;29884741;31444325;33963182                  somatic
# 17  27531699;29884741;31444325;33963182                  somatic
# 18                             33963182                  somatic
# 19                    29884741;31444325                  somatic
# 20  27531699;29884741;31444325;33963182                  somatic
# 21                    29884741;31444325                  somatic
#
#                Gene_Classification
# 0                   Not classified
# 1                   Not classified
# 2            Tumor Suppressor Gene
# 3                   Not classified
# 4            Tumor Suppressor Gene
# 5            Tumor Suppressor Gene
# 6                   Not classified
# 7            Tumor Suppressor Gene
# 8                   Not classified
# 9                         Oncogene
# 10           Tumor Suppressor Gene
# 11                  Not classified
# 12  Oncogene;Tumor Suppressor Gene
# 13                        Oncogene
# 14                  Not classified
# 15                        Oncogene
# 16                        Oncogene
# 17           Tumor Suppressor Gene
# 18           Tumor Suppressor Gene
# 19           Tumor Suppressor Gene
# 20           Tumor Suppressor Gene
# 21                  Not classified

# %%
genes = sorted(set([x for x in meta['HGNC_Gene_Symbol'] if not pd.isnull(x)]))
len(genes)
# Out:
# 22

# %%
# some genes have incorrect symbol name
m = {
    'HIST1H1E': 'H1-4',
}
genes = [m.get(g, g) for g in genes]

# %%
mg = mygene.MyGeneInfo()
result = mg.querymany(genes, scopes='symbol', fields='all', species='human')
# Out:
# querying 1-22...done.
# Finished.

# %%
df.to_csv(os.path.join(out_dir, 'formatted_beds', 'pecgs_mm.bed'), index=False, header=False, sep='\t')

# %% [markdown]
# ## CRC

# %%
meta = pd.read_csv(
    '/diskmnt/Projects/Users/estorrs/sandbox/pecgs_bed_files/gene_lists/crc_somatic_SELECTED_DRIVER_genes.tsv',
    sep='\t'
)
meta
# Out:
#    HGNC_Gene_Symbol                                     HGNC_Gene_Name  \
# 0            ACVR2A                         activin A receptor type 2A
# 1          ADAMTS18  ADAM metallopeptidase with thrombospondin type...
# 2             AMER1                 APC membrane recruitment protein 1
# 3               APC             APC regulator of WNT signaling pathway
# 4            ARID1A                      AT-rich interaction domain 1A
# 5              BRAF      B-Raf proto-oncogene, serine/threonine kinase
# 6              CBX4                                        chromobox 4
# 7             CSMD3                   CUB and Sushi multiple domains 3
# 8            CTNNB1                                     catenin beta 1
# 9             FBXW7            F-box and WD repeat domain containing 7
# 10             GNAS                                 GNAS complex locus
# 11            ITGB4                            integrin subunit beta 4
# 12             KRAS                        KRAS proto-oncogene, GTPase
# 13            LRP1B                    LDL receptor related protein 1B
# 14             NRAS                        NRAS proto-oncogene, GTPase
# 15            PCBP1                         poly(rC) binding protein 1
# 16           PIK3CA  phosphatidylinositol-4,5-bisphosphate 3-kinase...
# 17             PTEN                     phosphatase and tensin homolog
# 18            SMAD2                               SMAD family member 2
# 19            SMAD4                               SMAD family member 4
# 20             SOX9                     SRY-box transcription factor 9
# 21            SYNE1  spectrin repeat containing nuclear envelope pr...
# 22            TAF1L  TATA-box binding protein associated factor 1 like
# 23           TCF7L2                      transcription factor 7 like 2
# 24            TGIF1                     TGFB induced factor homeobox 1
# 25             TP53                                  tumor protein p53
# 26          ZFP36L2                   ZFP36 ring finger protein like 2
#
#                                        Gene_Alias(es)     HGNC_ID  \
# 0                                              ACTRII    HGNC:173
# 1                                                 NaN  HGNC:17110
# 2                          RP11-403E24.2;FLJ39827;WTX  HGNC:26837
# 3                               DP2;DP3;DP2.5;PPP1R46    HGNC:583
# 4                     B120;P270;C10rf4;BAF250;BAF250a  HGNC:11110
# 5                                               BRAF1   HGNC:1097
# 6                                      hPC2;PC2;NBP16   HGNC:1554
# 7                                                 NaN  HGNC:19291
# 8                              beta-catenin;armadillo   HGNC:2514
# 9     AGO;FLJ11071;SEL-10;SEL10;FBW7;FBX30;CDC4;FBXW6  HGNC:16712
# 10                  NESP55;NESP;GNASXL;GPSA;SCG6;SgVI   HGNC:4392
# 11                                              CD104   HGNC:6158
# 12                                      KRAS1;K-Ras4B   HGNC:6407
# 13                                     LRP-DIT;LRPDIT   HGNC:6693
# 14                                              N-ras   HGNC:7989
# 15                      HNRPE1;hnRNP-E1;HNRPX;hnRNP-X   HGNC:8647
# 16                                               PI3K   HGNC:8975
# 17                                   MMAC1;TEP1;PTEN1   HGNC:9588
# 18                                       MADR2;JV18-1   HGNC:6768
# 19                                               DPC4   HGNC:6770
# 20                                               SRA1  HGNC:11204
# 21  SYNE-1B;KIAA0796;8B;Nesprin-1;enaptin;MYNE1;CP...  HGNC:17089
# 22                                                NaN  HGNC:18056
# 23                                              TCF-4  HGNC:11641
# 24                                                NaN  HGNC:11776
# 25                                           p53;LFS1  HGNC:11998
# 26                                ERF2;RNF162C;TIS11D   HGNC:1108
#
#    Chromosome_location                                          Reference  \
# 0         2q22.3-q23.1  TCGA;Huang et al., 2018;Raskiv et al., 2020;Gu...
# 1              16q23.1  TCGA;Huang et al., 2018;Raskiv et al., 2020;Gu...
# 2               Xq11.2  TCGA;Huang et al., 2018;Raskiv et al., 2020;Gu...
# 3               5q22.2  TCGA;Huang et al., 2018;Raskiv et al., 2020;Gu...
# 4              1p36.11  TCGA;Huang et al., 2018;Raskiv et al., 2020;Gu...
# 5                 7q34  TCGA;Huang et al., 2018;Raskiv et al., 2020;Gu...
# 6              17q25.3  TCGA;Huang et al., 2018;Raskiv et al., 2020;Gu...
# 7               8q23.3  TCGA;Huang et al., 2018;Raskiv et al., 2020;Gu...
# 8               3p22.1  TCGA;Huang et al., 2018;Raskiv et al., 2020;Gu...
# 9               4q31.3  TCGA;Huang et al., 2018;Raskiv et al., 2020;Gu...
# 10            20q13.32  TCGA;Huang et al., 2018;Raskiv et al., 2020;Gu...
# 11             17q25.1  TCGA;Huang et al., 2018;Raskiv et al., 2020;Gu...
# 12             12p12.1  TCGA;Huang et al., 2018;Raskiv et al., 2020;Gu...
# 13        2q22.1-q22.2  TCGA;Huang et al., 2018;Raskiv et al., 2020;Gu...
# 14              1p13.2  TCGA;Huang et al., 2018;Raskiv et al., 2020;Gu...
# 15              2p13.3  TCGA;Huang et al., 2018;Raskiv et al., 2020;Gu...
# 16             3q26.32  TCGA;Huang et al., 2018;Raskiv et al., 2020;Gu...
# 17            10q23.31  TCGA;Huang et al., 2018;Raskiv et al., 2020;Gu...
# 18             18q21.1  TCGA;Huang et al., 2018;Raskiv et al., 2020;Gu...
# 19             18q21.2  TCGA;Huang et al., 2018;Raskiv et al., 2020;Gu...
# 20             17q24.3  TCGA;Huang et al., 2018;Raskiv et al., 2020;Gu...
# 21              6q25.2  TCGA;Huang et al., 2018;Raskiv et al., 2020;Gu...
# 22              9p21.1  TCGA;Huang et al., 2018;Raskiv et al., 2020;Gu...
# 23       10q25.2-q25.3  TCGA;Huang et al., 2018;Raskiv et al., 2020;Gu...
# 24            18p11.31  TCGA;Huang et al., 2018;Raskiv et al., 2020;Gu...
# 25             17p13.1  TCGA;Huang et al., 2018;Raskiv et al., 2020;Gu...
# 26                2p21  TCGA;Huang et al., 2018;Raskiv et al., 2020;Gu...
#
#                              Reference_PubMed_ID Reported_Mutation_Origin  \
# 0   22810696;29322354;31188207;26457759;31031003                  somatic
# 1   22810696;29322354;31188207;26457759;31031003                  somatic
# 2   22810696;29322354;31188207;26457759;31031003                  somatic
# 3   22810696;29322354;31188207;26457759;31031003                  somatic
# 4   22810696;29322354;31188207;26457759;31031003                  somatic
# 5   22810696;29322354;31188207;26457759;31031003                  somatic
# 6   22810696;29322354;31188207;26457759;31031003                  somatic
# 7   22810696;29322354;31188207;26457759;31031003                  somatic
# 8   22810696;29322354;31188207;26457759;31031003                  somatic
# 9   22810696;29322354;31188207;26457759;31031003                  somatic
# 10  22810696;29322354;31188207;26457759;31031003                  somatic
# 11  22810696;29322354;31188207;26457759;31031003                  somatic
# 12  22810696;29322354;31188207;26457759;31031003                  somatic
# 13  22810696;29322354;31188207;26457759;31031003                  somatic
# 14  22810696;29322354;31188207;26457759;31031003                  somatic
# 15  22810696;29322354;31188207;26457759;31031003                  somatic
# 16  22810696;29322354;31188207;26457759;31031003                  somatic
# 17  22810696;29322354;31188207;26457759;31031003                  somatic
# 18  22810696;29322354;31188207;26457759;31031003                  somatic
# 19  22810696;29322354;31188207;26457759;31031003                  somatic
# 20  22810696;29322354;31188207;26457759;31031003                  somatic
# 21  22810696;29322354;31188207;26457759;31031003                  somatic
# 22  22810696;29322354;31188207;26457759;31031003                  somatic
# 23  22810696;29322354;31188207;26457759;31031003                  somatic
# 24  22810696;29322354;31188207;26457759;31031003                  somatic
# 25  22810696;29322354;31188207;26457759;31031003                  somatic
# 26  22810696;29322354;31188207;26457759;31031003                  somatic
#
#       Gene_Classification
# 0   Tumor Suppressor Gene
# 1          Not classified
# 2   Tumor Suppressor Gene
# 3   Tumor Suppressor Gene
# 4   Tumor Suppressor Gene
# 5                Oncogene
# 6          Not classified
# 7   Tumor Suppressor Gene
# 8                Oncogene
# 9   Tumor Suppressor Gene
# 10               Oncogene
# 11         Not classified
# 12               Oncogene
# 13  Tumor Suppressor Gene
# 14               Oncogene
# 15         Not classified
# 16               Oncogene
# 17  Tumor Suppressor Gene
# 18  Tumor Suppressor Gene
# 19  Tumor Suppressor Gene
# 20         Not classified
# 21         Not classified
# 22         Not classified
# 23               Oncogene
# 24         Not classified
# 25  Tumor Suppressor Gene
# 26         Not classified

# %%
genes = sorted(set([x for x in meta['HGNC_Gene_Symbol'] if not pd.isnull(x)]))
len(genes)
# Out:
# 27

# %%
mg = mygene.MyGeneInfo()
result = mg.querymany(genes, scopes='symbol', fields='all', species='human')
# Out:
# querying 1-27...done.
# Finished.

# %%
df.to_csv(os.path.join(out_dir, 'formatted_beds', 'pecgs_crc.bed'), index=False, header=False, sep='\t')

# %% [markdown]
# ## Driver paper cancer types

# %%
meta = pd.read_csv('/diskmnt/Projects/Users/estorrs/sandbox/pecgs_bed_files/gene_lists/smg.bailey.cell.ct.tsv',
                   sep='\t')
meta
# Out:
#        Gene    Cancer              KEY  \
# 0      ABL1    PANCAN      ABL1_PANCAN
# 1     ACVR1      UCEC       ACVR1_UCEC
# 2    ACVR1B    PANCAN    ACVR1B_PANCAN
# 3    ACVR2A  COADREAD  ACVR2A_COADREAD
# 4    ACVR2A      LIHC      ACVR2A_LIHC
# ..      ...       ...              ...
# 734   ZMYM3      PRAD       ZMYM3_PRAD
# 735  ZNF133        OV        ZNF133_OV
# 736  ZNF750    PANCAN    ZNF750_PANCAN
# 737  ZNF750      ESCA      ZNF750_ESCA
# 738  ZNF750      HNSC      ZNF750_HNSC
#
#     Tumor suppressor or oncogene prediction (by 20/20+)  Decision  \
# 0                                                  NaN    rescued
# 1                                             oncogene   official
# 2                                         possible tsg   official
# 3                                                  tsg   official
# 4                                         possible tsg   official
# ..                                                 ...        ...
# 734                                                tsg   official
# 735                                           oncogene   official
# 736                                       possible tsg   official
# 737                                       possible tsg   official
# 738                                       possible tsg   official
#
#     Tissue Frequency Pancan Frequency  Consensus Score  \
# 0                NaN            1.17%              0.0
# 1              5.30%            0.75%              1.5
# 2                NaN            1.09%              1.0
# 3              2.85%            1.40%              1.5
# 4              3.11%            1.40%              1.5
# ..               ...              ...              ...
# 734            1.68%            1.85%              1.0
# 735            2.94%            0.61%              1.5
# 736              NaN            1.15%              1.5
# 737            6.98%            1.15%              2.5
# 738            3.78%            1.15%              2.5
#
#      Correlation adusted score  Novel  \
# 0                          NaN      0
# 1                          1.5      0
# 2                          0.0      0
# 3                          1.5      0
# 4                          1.5      0
# ..                         ...    ...
# 734                        0.0      1
# 735                        1.5      1
# 736                        1.5      0
# 737                        2.5      0
# 738                        2.5      0
#
#                                           Rescue Notes  \
# 0    Evidence from OncoImpact/DriverNET overlap (SN...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 734                                                NaN
# 735                                                NaN
# 736                                                NaN
# 737                                                NaN
# 738                                                NaN
#
#                        Note about previous publication
# 0                                                  NaN
# 1                                                    0
# 2                                    Found in 24132290
# 3                                    Found in 22810696
# 4    Found in private communication about integrati...
# ..                                                 ...
# 734                                  Found in 26544944
# 735                                  Found in 21720365
# 736                                                  0
# 737                                  Found in 28052061
# 738                                                  0
#
# [739 rows x 12 columns]

# %%
set(meta['Cancer'])
# Out:
# {'ACC',
#  'BLCA',
#  'BRCA',
#  'CESC',
#  'CHOL',
#  'COADREAD',
#  'DLBC',
#  'ESCA',
#  'GBM',
#  'HNSC',
#  'KICH',
#  'KIRC',
#  'KIRP',
#  'LAML',
#  'LGG',
#  'LIHC',
#  'LUAD',
#  'LUSC',
#  'MESO',
#  'OV',
#  'PAAD',
#  'PANCAN',
#  'PCPG',
#  'PRAD',
#  'SARC',
#  'SKCM',
#  'STAD',
#  'TGCT',
#  'THCA',
#  'THYM',
#  'UCEC',
#  'UCS',
#  'UVM'}

# %%
# some genes have incorrect symbol name
m = {
    'CBWD3': 'ZNG1C',
    'FAM46D': 'TENT5D',
    'H3F3A': 'H3-3A',
    'H3F3C': 'H3-5',
    'HIST1H1C': 'H1-2',
    'HIST1H1E': 'H1-4',
    'RQCD1': 'CNOT9',
    'TCEB1': 'ELOC',
    'WHSC1': 'NSD2'
}

# %%
for disease in sorted(set(meta['Cancer'])):
    print(disease)
    genes = meta[meta['Cancer']==disease]['Gene'].to_list()
    genes = [m.get(g, g) for g in genes]
    genes = sorted(set(genes))
    
    mg = mygene.MyGeneInfo()
    result = mg.querymany(genes, scopes='symbol', fields='all', species='human')
    
    df = result_to_df(result)
    df.to_csv(os.path.join(out_dir, 'formatted_beds', f'driver_paper_{disease}.bed'),
              index=False, header=False, sep='\t')
# Out:
# ACC
# querying 1-5...done.
# Finished.
# BLCA
# querying 1-45...done.
# Finished.
# BRCA
# querying 1-29...done.
# Finished.
# CESC
# querying 1-26...done.
# Finished.
# CHOL
# querying 1-5...done.
# Finished.
# COADREAD
# querying 1-20...done.
# Finished.
# DLBC
# querying 1-13...done.
# Finished.
# ESCA
# querying 1-13...done.
# Finished.
# GBM
# querying 1-17...done.
# Finished.
# HNSC
# querying 1-33...done.
# Finished.
# KICH
# querying 1-2...done.
# Finished.
# KIRC
# querying 1-12...done.
# Finished.
# KIRP
# querying 1-9...done.
# Finished.
# LAML
# querying 1-22...done.
# Finished.
# LGG
# querying 1-24...done.
# Finished.
# LIHC
# querying 1-32...done.
# Finished.
# LUAD
# querying 1-20...done.
# Finished.
# LUSC
# querying 1-22...done.
# Finished.
# MESO
# querying 1-5...done.
# Finished.
# OV
# querying 1-8...done.
# Finished.
# PAAD
# querying 1-11...done.
# Finished.
# PANCAN
# querying 1-200...done.
# Finished.
# PCPG
# querying 1-5...done.
# Finished.
# PRAD
# querying 1-15...done.
# Finished.
# SARC
# querying 1-3...done.
# Finished.
# SKCM
# querying 1-24...done.
# Finished.
# STAD
# querying 1-24...done.
# Finished.
# TGCT
# querying 1-5...done.
# Finished.
# THCA
# querying 1-9...done.
# Finished.
# THYM
# querying 1-4...done.
# Finished.
# UCEC
# querying 1-55...done.
# Finished.
# UCS
# querying 1-14...done.
# Finished.
# UVM
# querying 1-8...done.
# Finished.

# %% [markdown]
# ## Drivers

# %%
genes = pd.read_csv('/diskmnt/Projects/Users/estorrs/sandbox/pecgs_bed_files/gene_lists/cancer_gene_list_cell_uniq.tsv',
                   sep='\t', header=None)
genes = genes[0]
len(genes), len(set(genes))
# Out:
# (299, 299)

# %%
# some genes have incorrect symbol name
m = {
    'CBWD3': 'ZNG1C',
    'FAM46D': 'TENT5D',
    'H3F3A': 'H3-3A',
    'H3F3C': 'H3-5',
    'HIST1H1C': 'H1-2',
    'HIST1H1E': 'H1-4',
    'RQCD1': 'CNOT9',
    'TCEB1': 'ELOC',
    'WHSC1': 'NSD2'
}
genes = [m.get(g, g) for g in genes]

# %%
mg = mygene.MyGeneInfo()
result = mg.querymany(genes, scopes='symbol', fields='all', species='human')
# Out:
# querying 1-299...done.
# Finished.

# %%
df = result_to_df(result)
df
# Out:
#       chr      start       stop     gene
# 234  chr1    6185020    6185020    RPL22
# 168  chr1   11106535   11106535     MTOR
# 85   chr1   16124337   16124337    EPHA2
# 14   chr1   26693236   26693236   ARID1A
# 272  chr1   36224432   36224432   THRAP3
# ..    ...        ...        ...      ...
# 291  chrX  118823824  118823824  ZCCHC12
# 261  chrX  123960212  123960212    STAG2
# 249  chrX  129446501  129446501  SMARCA1
# 192  chrX  134373288  134373288     PHF6
# 99   chrX  154348524  154348524     FLNA
#
# [299 rows x 4 columns]

# %%
df.to_csv(os.path.join(out_dir, 'formatted_beds', '299_drivers.bed'), index=False, header=False, sep='\t')
